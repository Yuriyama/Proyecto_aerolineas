# %% [markdown]
# # Figuras Tesis

# %%
using LightGraphs
# Out:
# ┌ Info: Recompiling stale cache file /Users/yuriko/.julia/compiled/v1.1/LightGraphs/Xm08G.ji for LightGraphs [093fc24a-ae57-5d10-9952-331d41423f4d]
# └ @ Base loading.jl:1184

# %%
using Gadfly

# %%
using Colors

# %%
using Plots
pyplot()

# %%
using Graphs
# Out:
# ┌ Info: Recompiling stale cache file /Users/yuriko/.julia/compiled/v1.1/Graphs/VJ6vx.ji for Graphs [86223c79-3864-5bf0-83f7-82e725a168b6]
# └ @ Base loading.jl:1184
# WARNING: using Graphs.SimpleGraph in module Main conflicts with an existing identifier.

# %%
using Compose
# Out:
# ┌ Info: Precompiling Compose [a81c6b42-2e10-5240-aca2-a61377ecd94b]
# └ @ Base loading.jl:1186

# %%
using Pkg
Pkg.rm("GraphPlot")

# %%
Pkg.rm("json")

# %%
Pkg.update()

# %%
Pkg.status()

# %%
Pkg.add("GraphPlot")

# %%
using GraphPlot
# Out:
# ┌ Info: Precompiling GraphPlot [a2cc645c-3eea-5389-862e-a155d0052231]
# └ @ Base loading.jl:1186

# %%
Pkg.add("JSON")

# %%
using GraphPlot

# %%
Pkg.status()

# %%
using GraphPlot 
using Compose

# %% [markdown]
# ## Tipo de Redes

# %%
w = WheelGraph(10)
# Out:
# ┌ Warning: `WheelGraph` is deprecated, use `wheel_graph` instead.
# │   caller = top-level scope at In[46]:1
# └ @ Core In[46]:1
# {10, 18} undirected simple Int64 graph

# %%
gplot(w)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.0407294cx, -0.0636716cy), (0.734285cx, -0.576967cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.00382585cx, -0.0933833cy), (0.201542cx, -0.923258cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.0583714cx, -0.0872521cy), (-0.441452cx, -0.848049cy)]), LinePrimitive{Tuple{Measure,Meas
# ...

# %%
g = graphfamous("karate")
# Out:
# {34, 78} undirected simple Int64 graph

# %%
typeof(g)
# Out:
# SimpleGraph{Int64}

# %%
gplot(g)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.120672cx, 0.198768cy), (0.0214214cx, 0.0957717cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.162621cx, 0.181671cy), (-0.223201cx, -0.172231cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.195314cx, 0.208309cy), (-0.401942cx, 0.127466cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tu
# ...

# %%
nodelabel = [1:num_vertices(g)]
gplot(g, nodelabel)
# Out:
# MethodError: no method matching num_vertices(::SimpleGraph{Int64})
# Closest candidates are:
#   num_vertices(!Matched::GenericEdgeList) at /Users/yuriko/.julia/packages/Graphs/GQCid/src/edge_list.jl:27
#   num_vertices(!Matched::GenericAdjacencyList) at /Users/yuriko/.julia/packages/Graphs/GQCid/src/adjacency_list.jl:36
#   num_vertices(!Matched::GenericIncidenceList) at /Users/yuriko/.julia/packages/Graphs/GQCid/src/incidence_list.jl:47
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[57]:1

# %%
?num_vertices
# Out:
# search: num_vertices
#   No documentation found.
#
#   Graphs.num_vertices is a Function.
#
#   # 4 methods for generic function "num_vertices":
#   [1] num_vertices(g::GenericEdgeList) in Graphs at /Users/yuriko/.julia/packages/Graphs/GQCid/src/edge_list.jl:27
#   [2] num_vertices(g::GenericAdjacencyList) in Graphs at /Users/yuriko/.julia/packages/Graphs/GQCid/src/adjacency_list.jl:36
#   [3] num_vertices(g::GenericIncidenceList) in Graphs at /Users/yuriko/.julia/packages/Graphs/GQCid/src/incidence_list.jl:47
#   [4] num_vertices(g::GenericGraph) in Graphs at /Users/yuriko/.julia/packages/Graphs/GQCid/src/graph.jl:57

# %%
nodesize = [Graphs.out_degree(v, g) for v in Graphs.vertices(g)]
gplot(g, nodesize=nodesize)
# Out:
# MethodError: no method matching vertices(::SimpleGraph{Int64})
# Closest candidates are:
#   vertices(!Matched::GenericEdgeList) at /Users/yuriko/.julia/packages/Graphs/GQCid/src/edge_list.jl:28
#   vertices(!Matched::GenericAdjacencyList) at /Users/yuriko/.julia/packages/Graphs/GQCid/src/adjacency_list.jl:37
#   vertices(!Matched::GenericIncidenceList) at /Users/yuriko/.julia/packages/Graphs/GQCid/src/incidence_list.jl:54
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[55]:1

# %%
?Graphs.vertices
# Out:
#   No documentation found.
#
#   Graphs.vertices is a Function.
#
#   # 4 methods for generic function "vertices":
#   [1] vertices(g::GenericEdgeList) in Graphs at /Users/yuriko/.julia/packages/Graphs/GQCid/src/edge_list.jl:28
#   [2] vertices(g::GenericAdjacencyList) in Graphs at /Users/yuriko/.julia/packages/Graphs/GQCid/src/adjacency_list.jl:37
#   [3] vertices(g::GenericIncidenceList) in Graphs at /Users/yuriko/.julia/packages/Graphs/GQCid/src/incidence_list.jl:54
#   [4] vertices(g::GenericGraph) in Graphs at /Users/yuriko/.julia/packages/Graphs/GQCid/src/graph.jl:58

# %%
#watts_strogatz(n, k, β)
#Return a Watts-Strogatz small model random graph with n vertices, each with 
#degree k. Edges are randomized per the model based on probability β.
h = watts_strogatz(50, 5, 0.3)
gplot(h)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.416532cx, 0.327384cy), (0.624713cx, 0.610355cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.417043cx, 0.327001cy), (0.493058cx, 0.426509cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.382322cx, 0.266131cy), (0.171167cx, -0.255866cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Mea
# ...

# %%
#erdos_renyi(n, ne)
#Create an Erdős–Rényi random graph with n vertices and ne edges.
e = erdos_renyi(10, 20)
gplot(e)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.31828cx, 0.205632cy), (-0.328884cx, 0.150004cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.335047cx, 0.261454cy), (0.107296cx, 0.441639cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.336902cx, 0.161094cy), (-0.379547cx, -0.4501cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Meas
# ...

# %%
e = erdos_renyi(10, 20, is_directed=true)
gplot(e)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.0160595cx, 0.387867cy), (-0.235634cx, -0.346896cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.961619cx, 0.25603cy), (0.668964cx, -0.270974cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.932311cx, 0.284303cy), (0.463703cx, 0.00155167cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple
# ...

# %%
#erdos_renyi(n, p)
#Create an Erdős–Rényi random graph with n vertices. Edges are added between pairs of vertices with probability p.
r = erdos_renyi(10, 0.4)
gplot(r)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.685674cx, 0.614754cy), (0.755394cx, 0.707246cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.620083cx, 0.474644cy), (0.525972cx, 0.0722244cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(0.716197cx, 0.563815cy), (0.921889cx, 0.595918cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Mea
# ...

# %%
#barabasi_albert(n, k) Preferential attachment
#Create a Barabási–Albert model random graph with n vertices. It is grown by adding 
#new vertices to an initial graph with k vertices. Each new vertex is attached with 
#k edges to k different vertices already present in the system by preferential attachment. 
#Initial graphs are undirected and consist of isolated vertices by default.

b = barabasi_albert(20, 5, is_directed=true, complete=false, seed=1)
# Out:
# {20, 75} directed simple Int64 graph

# %%
gplot(b)
# Out:
# Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.0972583cx, -0.0496314cy), (-0.292507cx, -0.945381cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.14064cx, -0.00327724cy), (-0.331291cx, -0.0317782cy)]), LinePrimitive{Tuple{Measure,Measure}}(Tuple{Measure,Measure}[(-0.116798cx, 0.0512072cy), (-0.25224cx, 0.250289cy)]), LinePrimitive{Tuple{Measure,Measur
# ...

# %%
gplot(WheelGraph(10))
# Out:
# ┌ Warning: `WheelGraph` is deprecated, use `wheel_graph` instead.
# │   caller = top-level scope at In[8]:1
# └ @ Core In[8]:1
# ...
